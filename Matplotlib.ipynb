# %%
from matplotlib import pyplot as plt

# %% [markdown]
# <h2>Line Plots<h2>

# %%
dev_x = [i for i in range(25,36)]
dev_y = [38496,42000,46752,49320,52300,56000,62316,64928,67317,68419,72148]
plt.plot(dev_x,dev_y) #Use 'plot' function to create a simple line plot between 2 continuous variables.
plt.show()

# %%
#Include labels for both axes and plot title.
plt.xlabel('Age')
plt.ylabel('Median Salary(USD)')
plt.title('Median Salary(USD) by Age')
plt.plot(dev_x,dev_y)
plt.show()

# %%
#For a common x-axis, we plot a line chart for 2 different y-axis variables.
pydev_y = [45321,47234,49456,56378,60124,63456,65487,68426,70210,74178,75125]
plt.xlabel('Age')
plt.ylabel('Median Salary(USD)')
plt.title('Median Salary(USD) by Age')
plt.plot(dev_x,dev_y,label='For all devs') #Included 2 plot functions, one for each line chart.
plt.plot(dev_x,pydev_y,label='For Python devs') 
plt.legend() #To differentiate b/w the lines, we include 'label' option in both 'plot' functions and then include a legend.
plt.show()

# %%
#We do some color, linestyle and marker related customization to our line plot.
plt.plot(dev_x,dev_y,color='#444444',linestyle='--',marker='o',linewidth=3,label='For all devs') 
plt.plot(dev_x,pydev_y,color='#5a79da',marker='.',linewidth=3, label='For Python devs') 
plt.legend() #The values in 'color' option are hex color values. Can be taken online as per need.
plt.grid(True)

# %%
#Choose from the different available plotting styles.
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
#Now we remove the custom color/line settings and simply include the style in 'style.use' fucntion.
plt.plot(dev_x,dev_y,label='For all devs') 
plt.plot(dev_x,pydev_y, label='For Python devs') 
plt.legend() #The values in 'color' option are hex color values. Can be taken online as per need.
plt.style.use('seaborn-talk')
plt.grid(True)
#plt.savefig('Path:/plot.png') This saves the created plot on local machine's directory.

# %% [markdown]
# <h2>Bar Plots<h2>

# %%
jsdev_y = [37321,43534,46456,49778,53124,56456,62487,66426,68210,68178,75125]
plt.bar(dev_x,dev_y,label='All Devs')
plt.bar(dev_x,pydev_y,label='Python Devs')
plt.bar(dev_x,jsdev_y,label='Java Devs')
plt.style.use('seaborn-poster')
plt.legend()
plt.show()
#As seen, the 3 bars are stacked over each other rather than be shown side-by-side.
#To resolve it, we include a width offset on each bar so that they appear separately rather than on top.

# %%
import numpy as np
x_index = np.arange(len(dev_x))
width=0.25
plt.bar(x_index-width,dev_y,width=width,label='All Devs') #Shift the bar to the left.
plt.bar(x_index,pydev_y,width=width,label='Python Devs') #Bar remains as it is.
plt.bar(x_index+width,jsdev_y,width=width,label='Java Devs') #Shift the bar to the right.
plt.title('Media Salary(USD) by Age')
plt.xlabel('Age')
plt.ylabel('Median Salary(USD)')
plt.legend()
plt.show()
#By including the width offset, the bars are now aligned side-by-side.

# %%
#To offset our bars, we changed our x-axis from actual age values to indices. As offsetting actual data doesn't fit the pupose.
#However, it's not good to see indices instead of actual age figures on our bar plot.
#To include the ages again on x-axis, we use 'xticks' function as follows.
plt.xticks(ticks=x_index,labels=dev_x)
plt.bar(x_index-width,dev_y,width=width,label='All Devs') #Shift the bar to the left.
plt.bar(x_index,pydev_y,width=width,label='Python Devs') #Bar remains as it is.
plt.bar(x_index+width,jsdev_y,width=width,label='Java Devs') #Shift the bar to the right.
plt.title('Media Salary(USD) by Age')
plt.xlabel('Age')
plt.ylabel('Median Salary(USD)')
plt.legend()

# %%
#We have 'data.csv' file having the 'Responder_id' and 'LanguagesWorkedWith' column.
import csv
with open('D:/pandas Practice/data.csv') as csv_file:
    csv_reader = csv.DictReader(csv_file) #We know that a dataset is nothing but a dictionary with column names as 'keys' and column values as 'values'.
    #This 'csv_reader' object is a dictionary dataset which can be looped over for each row to get whole data. However, it can't be printed alone.
    row = next(csv_reader) #This commands extracts the first iteration of the dictionary object.
    print(row) #Hence we get the 1st record values as Key:value pairs.
# Out:
# {'Responder_id': '1', 'LanguagesWorkedWith': 'HTML/CSS;Java;JavaScript;Python'}

# %%
print(row['LanguagesWorkedWith']) #Extracting only the 'LanguagesWorkedWith' key to get its corresponding value.
# Out:
# HTML/CSS;Java;JavaScript;Python

# %%
print(row['LanguagesWorkedWith'].split(';'))
#We get a list output having the name of all languages worked with for the first responder ID.
# Out:
# ['HTML/CSS', 'Java', 'JavaScript', 'Python']

# %%
from collections import Counter
c=Counter(['Auba','Laca','Saka','Auba','Saka'])
c #The 'Counter' function takes in a list argument and returns count of each value occuring in the list as key:value pairs.
# Out:
# Counter({'Auba': 2, 'Laca': 1, 'Saka': 2})

# %%
with open('D:/pandas Practice/data.csv') as csv_file:
    csv_reader = csv.DictReader(csv_file) #The 'DictReader' creates a dictionary object out of the 'data.csv' file.
    count_languages = Counter() #Create an empty counter which later updates and takes in list arguments from each iteration of 'for' loop.
    for i in csv_reader: #At the end of last iteration, it will return the count of each unique value of the list generated after split.
        count_languages.update(i['LanguagesWorkedWith'].split(';'))
print(count_languages)
# Out:
# Counter({'JavaScript': 59219, 'HTML/CSS': 55466, 'SQL': 47544, 'Python': 36443, 'Java': 35917, 'Bash/Shell/PowerShell': 31991, 'C#': 27097, 'PHP': 23030, 'C++': 20524, 'TypeScript': 18523, 'C': 18017, 'Other(s):': 7920, 'Ruby': 7331, 'Go': 7201, 'Assembly': 5833, 'Swift': 5744, 'Kotlin': 5620, 'R': 5048, 'VBA': 4781, 'Objective-C': 4191, 'Scala': 3309, 'Rust': 2794, 'Dart': 1683, 'Elixir': 1260, 'Clojure': 1254, 'WebAssembly': 1015, 'F#': 973, 'Erlang': 777})

# %%
import pandas as pd
df = pd.DataFrame.from_dict(count_languages,orient='index').reset_index()
df.rename(columns={'index':'LanguagesWorkedWith',0:'Count'},inplace=True)
df.head(3)
# Out:
#   LanguagesWorkedWith  Count
# 0            HTML/CSS  55466
# 1                Java  35917
# 2          JavaScript  59219

# %%
#Now we have our original 'LanguagesWorkedWith' column as 2 separate columns, one having name of languages and other having the counts.
#Basically, we arrived at an object which tells us the count of each language as it appears in the original messy column.
#Now we can plot the languages with their popularity of usage.
plt.barh(df['LanguagesWorkedWith'],df['Count']) #Plot a horizontal bar instead of vertical.
plt.title('Usage of Languages')
plt.xlabel('Count of Users')
plt.ylabel('Languages')
# Out:
# Text(0, 0.5, 'Languages')

# %%
#We can alternately use 'pandas' instead of 'open' and 'DictReader'.
data = pd.read_csv('D:/pandas Practice/data.csv')
ids = data['Responder_id']
languages_known = data['LanguagesWorkedWith']
lang_counter = Counter()
for i in languages_known:
    lang_counter.update(i.split(';'))
print(lang_counter)
# Out:
# Counter({'JavaScript': 59219, 'HTML/CSS': 55466, 'SQL': 47544, 'Python': 36443, 'Java': 35917, 'Bash/Shell/PowerShell': 31991, 'C#': 27097, 'PHP': 23030, 'C++': 20524, 'TypeScript': 18523, 'C': 18017, 'Other(s):': 7920, 'Ruby': 7331, 'Go': 7201, 'Assembly': 5833, 'Swift': 5744, 'Kotlin': 5620, 'R': 5048, 'VBA': 4781, 'Objective-C': 4191, 'Scala': 3309, 'Rust': 2794, 'Dart': 1683, 'Elixir': 1260, 'Clojure': 1254, 'WebAssembly': 1015, 'F#': 973, 'Erlang': 777})

# %%
df = pd.DataFrame.from_dict(lang_counter,orient='index').reset_index()
df.rename(columns={'index':'LanguagesWorkedWith',0:'Count'},inplace=True)
df.head(3)
#We can plot this exactly like we did earlier.
# Out:
#   LanguagesWorkedWith  Count
# 0            HTML/CSS  55466
# 1                Java  35917
# 2          JavaScript  59219

# %% [markdown]
# <h2>Pie Charts<h2>

# %%
slices = [15,25,35,25]
labels = ['Matlab','SQL','Python','R']
color = ['#d690bb','#a6edb9','#8890db','#deb78a'] #Hex color codes found online.
plt.pie(slices,labels=labels,colors=color)
plt.title('Analytical Tools by Popularity')
plt.show()

# %%
#The 'explode' option takes in a list of values as a proportion. 
exp = [0,0,0.07,0] #Here we explode the 'Python' slice by 7% in the pie chart so that it pops out distinctly.
plt.pie(slices,labels=labels,colors=color,explode=exp,shadow=True,autopct='%1.1f%%') #'shadow' option includes a 3d effect on the chart.
plt.show() #The 'autopct' option includes the percentage share of each slice in the pie-chart. The value '%1.1f%%' is given as it is.

# %% [markdown]
# <h2>Area Plots<h2>
# <h3>Used mainly when we have timestamps on x-axis and we want to plot productivity/output of multiple individuals/entities on y-axis.

# %%
players = ['Auba','ESR','Saka']
timestamps = [15,30,45,60,75,90]
auba = [2.2,3.5,4.2,5.7,7.5,8.3] #Ground covered in kms. till given timestamps.
esr = [2.5,4.1,5.3,6.8,7.9,9.5]
saka = [2.4,3.6,4.2,5.5,6.7,7.9]
color = ['#d690bb','#a6edb9','#8890db']
plt.stackplot(timestamps,auba,esr,saka,labels=players,colors=color)
plt.legend(loc='upper left') #Option to customize the location of legend as per the plot.
plt.show()

# %%
days = ['Mon','Tue','Wed','Thu','Fri']
Edward = [5,6,4,3,2]
Hahn = [3,4,2,5,4]
Chang = [2,4,3,6,5]
devs = ['Edward','Hahn','Chang']
plt.stackplot(days,Edward,Hahn,Chang,labels=devs)
plt.ylabel('Work Hrs.')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# <h2>Fill Area in Line Plot<h2>

# %%
dev_x = [i for i in range(25,36)]
dev_y = [38496,42000,46752,49320,52300,56000,62316,64928,67317,68419,72148]
pydev_y = [45321,47234,49456,56378,60124,63456,65487,68426,70210,74178,75125]
plt.plot(dev_x,dev_y,label='All Devs')
plt.plot(dev_x,pydev_y,label='Python Devs')
plt.fill_between(dev_x,pydev_y,alpha=0.3) 
plt.xlabel('Age')
plt.ylabel('Median Salary(USD)')
plt.legend() #Option 'alpha' included to make the fill more transparent so that both lines are clearly visible.
plt.show()

# %%
#Include a point where the fill shows differently above and below the point.
median_salary = 57_000
plt.plot(dev_x,dev_y,label='All Devs')
plt.plot(dev_x,pydev_y,label='Python Devs')
plt.fill_between(dev_x,pydev_y,median_salary,alpha=0.3) 
plt.xlabel('Age')
plt.ylabel('Median Salary(USD)')
plt.legend() 
plt.show()

# %%
#We can use a 'where' option to indicate the color pattern based on a criteria.
plt.plot(dev_x,dev_y,label='All Devs')
plt.plot(dev_x,pydev_y,label='Python Devs')
plt.fill_between(dev_x,pydev_y,median_salary,where=([i>median_salary for i in pydev_y]),color='#0e8f5d',interpolate=True) 
plt.fill_between(dev_x,pydev_y,median_salary,where=([i<=median_salary for i in pydev_y]),color='#bd243d',interpolate=True)

# %%
#To fill between regions, specify first the x-axis argument(i.e.'dev_x')followed by the 2 y-axis arguments between which we want the fill.
jsdev_y = [37321,43534,43456,49778,53124,51456,62487,66426,68210,68178,75125]
plt.plot(dev_x,dev_y,label='All Devs')
plt.plot(dev_x,pydev_y,label='Python Devs')
plt.plot(dev_x,jsdev_y,label='Java Devs')
plt.fill_between(dev_x,jsdev_y,pydev_y,alpha=0.3) #Fill between all devs and java devs.
plt.fill_between(dev_x,dev_y,jsdev_y,alpha=0.3) #Fill between java devs and python devs.
plt.xlabel('Age')
plt.ylabel('Median Salary(USD)')
plt.legend() 
plt.show()

# %% [markdown]
# <h2>Histograms<h2>

# %%
import pandas as pd
d21 = pd.read_csv('D:/pandas Practice/data1.csv')
ids = d21['Responder_id']
age = d21['Age']
bins = [10,20,30,40,60,90]
plt.hist(age,bins=bins,edgecolor='black')
plt.show()

# %%
#Include a vertical line showing a statistic eg. mean/media etc.
median = 32
plt.hist(age,bins=bins,edgecolor='black')
plt.axvline(median,color='#61eb34',label='Median Age')
plt.title('Distribution of Age')
plt.ylabel('Count')
plt.xlabel('Age Bins')
plt.legend()
plt.show()

# %% [markdown]
# <h2>Scatter Plots<h2>

# %%
d2 = pd.read_csv('D:/pandas Practice/data2.csv')
views = d2['view_count']
likes = d2['likes']
ratio = d2['ratio']
plt.scatter(views,likes,edgecolor='black',alpha=0.75,linewidth=1)
plt.title('Trending YT Videos')
plt.xlabel('Views')
plt.ylabel('Likes')
plt.show()
#As seen, an outlier data point distorts and disrupts the plot.

# %%
#We can use a logarithmic scale to nullify outlier effect and get a clearer picture of the distribution.
plt.xscale('log')
plt.yscale('log') 
plt.scatter(views,likes,edgecolor='black',alpha=0.75,linewidth=1,c=ratio)#The 'c' option sets the color intensity for the data points. 
cbar = plt.colorbar() #Include a color bar with the plot.
cbar.set_label('Like/Dislike Ratio') #Set a label for the color bar.
plt.title('Trending YT Videos') 
plt.xlabel('Views')
plt.ylabel('Likes')
plt.show()
